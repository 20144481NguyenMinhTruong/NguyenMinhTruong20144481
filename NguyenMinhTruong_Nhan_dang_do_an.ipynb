# %% [markdown]
# <a href="https://colab.research.google.com/github/20144481NguyenMinhTruong/NguyenMinhTruong20144481/blob/main/NguyenMinhTruong_Nhan_dang_do_an.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BTVN/FOOD
# Out:
# /content/drive/MyDrive/Colab Notebooks/BTVN/FOOD

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/FOOD/Train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 75 images belonging to 4 classes.

# %%
# Tạo bộ dữ liệu validation
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/FOOD/Validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 53 images belonging to 4 classes.

# %%
# Các nhãn có trong bộ dữ liệu training set
training_set.class_indices
# Out:
# {'banh bao': 0, 'banh mi': 1, 'bun gio': 2, 'xoi gac': 3}

# %%
# Các nhãn có trong bộ dữ liệu validation
validation.class_indices
# Out:
# {'banh bao': 0, 'banh mi': 1, 'bun gio': 2, 'xoi gac': 3}

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()
# Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Duỗi thẳng dữ liệu 
model.add(Flatten())
# Tạo lớp ẩn thứ nhất với 128 tín hiệu ra
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
# Tạo lớp ẩn thứ hai với 3 tín hiệu ra
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 150, 150, 32)      896
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 41472)             0
#
#  dense_2 (Dense)             (None, 128)               5308544
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 5,596,068
# Trainable params: 5,596,068
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), khi sai số không thay đổi trong 20 lần học thì sẽ␣ dừng học 
history=model.fit(training_set,epochs=500,batch_size=128,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/500
# 3/3 [==============================] - 31s 12s/step - loss: 6.7021 - accuracy: 0.2000 - val_loss: 2.9006 - val_accuracy: 0.2642
# Epoch 2/500
# 3/3 [==============================] - 14s 4s/step - loss: 2.0354 - accuracy: 0.3333 - val_loss: 1.2216 - val_accuracy: 0.3585
# Epoch 3/500
# 3/3 [==============================] - 14s 4s/step - loss: 1.2110 - accuracy: 0.4000 - val_loss: 1.0876 - val_accuracy: 0.4717
# Epoch 4/500
# 3/3 [==============================] - 14s 4s/step - loss: 1.0682 - accuracy: 0.3867 - val_loss: 0.8541 - val_accuracy: 0.5472
# Epoch 5/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.8177 - accuracy: 0.6267 - val_loss: 0.7404 - val_accuracy: 0.6792
# Epoch 6/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.7243 - accuracy: 0.6800 - val_loss: 0.6061 - val_accuracy: 0.7925
# Epoch 7/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.5921 - accuracy: 0.7733 - val_loss: 0.6519 - val_accuracy: 0.6604
# Epoch 8/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.6721 - accuracy: 0.6667 - val_loss: 0.5555 - val_accuracy: 0.7925
# Epoch 9/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.4956 - accuracy: 0.8000 - val_loss: 0.3405 - val_accuracy: 0.8679
# Epoch 10/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.4017 - accuracy: 0.8400 - val_loss: 0.3421 - val_accuracy: 0.8679
# Epoch 11/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.3282 - accuracy: 0.8800 - val_loss: 0.2913 - val_accuracy: 0.8491
# Epoch 12/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.4423 - accuracy: 0.8400 - val_loss: 0.6007 - val_accuracy: 0.6981
# Epoch 13/500
# 3/3 [==============================] - 15s 4s/step - loss: 0.7649 - accuracy: 0.6533 - val_loss: 0.4956 - val_accuracy: 0.8113
# Epoch 14/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.5068 - accuracy: 0.8000 - val_loss: 0.2322 - val_accuracy: 0.9245
# Epoch 15/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.3116 - accuracy: 0.9067 - val_loss: 0.4998 - val_accuracy: 0.7736
# Epoch 16/500
# 3/3 [==============================] - 15s 6s/step - loss: 0.4198 - accuracy: 0.8267 - val_loss: 0.2042 - val_accuracy: 0.9811
# Epoch 17/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.2707 - accuracy: 0.9067 - val_loss: 0.3798 - val_accuracy: 0.9245
# Epoch 18/500
# Epoch 60/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.1557 - accuracy: 0.9333 - val_loss: 0.2065 - val_accuracy: 0.9434
# Epoch 61/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.1661 - accuracy: 0.9200 - val_loss: 0.0716 - val_accuracy: 0.9434
# Epoch 62/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.1104 - accuracy: 0.9600 - val_loss: 0.0429 - val_accuracy: 0.9811
# Epoch 63/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.1343 - accuracy: 0.9600 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 64/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9811
# Epoch 65/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.0959 - accuracy: 0.9733 - val_loss: 0.0393 - val_accuracy: 0.9811
# Epoch 66/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.0547 - accuracy: 0.9867 - val_loss: 0.0899 - val_accuracy: 0.9811
# Epoch 67/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.1115 - accuracy: 0.9600 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 68/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.1026 - accuracy: 0.9733 - val_loss: 0.0552 - val_accuracy: 0.9811
# Epoch 69/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.0796 - accuracy: 0.9733 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 70/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.1043 - accuracy: 0.9733 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 71/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0316 - accuracy: 0.9867 - val_loss: 0.1244 - val_accuracy: 0.9434
# Epoch 72/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0476 - accuracy: 0.9733 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 73/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.1190 - accuracy: 0.9867 - val_loss: 0.0216 - val_accuracy: 0.9811
# Epoch 74/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9811
# Epoch 75/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9623
# Epoch 76/500
# 3/3 [==============================] - 15s 4s/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.9811
# Epoch 77/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 78/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 79/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0310 - accuracy: 0.9867 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 80/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 81/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 82/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 83/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 4.6786e-04 - val_accuracy: 1.0000
# Epoch 84/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.6133e-04 - val_accuracy: 1.0000
# Epoch 85/500
# 3/3 [==============================] - 14s 6s/step - loss: 5.6116e-04 - accuracy: 1.0000 - val_loss: 2.7400e-04 - val_accuracy: 1.0000
# Epoch 86/500
# 3/3 [==============================] - 15s 5s/step - loss: 6.0511e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 87/500
# 3/3 [==============================] - 15s 5s/step - loss: 3.9176e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 88/500
# 3/3 [==============================] - 14s 4s/step - loss: 8.1104e-04 - accuracy: 1.0000 - val_loss: 1.0454e-04 - val_accuracy: 1.0000
# Epoch 89/500
# 3/3 [==============================] - 15s 5s/step - loss: 2.5810e-04 - accuracy: 1.0000 - val_loss: 6.6328e-04 - val_accuracy: 1.0000
# Epoch 90/500
# 3/3 [==============================] - 15s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.0515e-04 - val_accuracy: 1.0000
# Epoch 91/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 92/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9623
# Epoch 93/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.0790e-04 - val_accuracy: 1.0000
# Epoch 94/500
# 3/3 [==============================] - 14s 6s/step - loss: 3.4910e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 95/500
# 3/3 [==============================] - 14s 6s/step - loss: 9.7308e-04 - accuracy: 1.0000 - val_loss: 5.6577e-04 - val_accuracy: 1.0000
# Epoch 96/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0628 - accuracy: 0.9867 - val_loss: 0.2417 - val_accuracy: 0.9434
# Epoch 97/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.3018 - accuracy: 0.9333 - val_loss: 0.0663 - val_accuracy: 0.9623
# Epoch 98/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0958 - accuracy: 0.9733 - val_loss: 0.0648 - val_accuracy: 0.9811
# Epoch 99/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.1002 - accuracy: 0.9867 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 100/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0247 - accuracy: 0.9867 - val_loss: 0.0237 - val_accuracy: 0.9811
# Epoch 101/500
# 3/3 [==============================] - 14s 5s/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9811
# Epoch 102/500
# 3/3 [==============================] - 15s 4s/step - loss: 0.1483 - accuracy: 0.9733 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 103/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 104/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0287 - accuracy: 0.9867 - val_loss: 0.0869 - val_accuracy: 0.9811
# Epoch 105/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 106/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.0894 - accuracy: 0.9867 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 107/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 108/500
# 3/3 [==============================] - 15s 4s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9811
# Epoch 109/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.3182 - accuracy: 0.9733 - val_loss: 0.0919 - val_accuracy: 0.9811
# Epoch 110/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0728 - accuracy: 0.9867 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 111/500
# 3/3 [==============================] - 14s 4s/step - loss: 0.0420 - accuracy: 0.9733 - val_loss: 0.0723 - val_accuracy: 0.9623
# Epoch 112/500
# 3/3 [==============================] - 15s 4s/step - loss: 0.0548 - accuracy: 0.9733 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 113/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 114/500
# 3/3 [==============================] - 15s 5s/step - loss: 0.0194 - accuracy: 0.9867 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 115/500
# 3/3 [==============================] - 15s 6s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 116/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 117/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 5.6381e-04 - val_accuracy: 1.0000
# Epoch 118/500
# 3/3 [==============================] - 14s 6s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 5.0202e-04 - val_accuracy: 1.0000

# %%
model.save('mon_an.h5')

# %%
model_ma = load_model('mon_an.h5')

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.028501277789473534
# Train Accuracy 0.9866666793823242

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
test="/content/drive/MyDrive/Colab Notebooks/BTVN/FOOD/nhan dang"

for i in os.listdir(test):
  img=load_img(test+'/'+i,target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=model_ma.predict(img)
  if round(result[0][0])==1:
    prediction='banh bao'
  if round(result[0][1])==1:
    prediction='banh mi'
  if round(result[0][2])==1:
    prediction='bun gio'
  if round(result[0][3])==1:
    prediction='xoi gac'
  print(prediction)
  plt.show()
# Out:
# 1/1 [==============================] - 0s 56ms/step
# banh bao
# 1/1 [==============================] - 0s 55ms/step
# banh bao
# 1/1 [==============================] - 0s 55ms/step
# banh bao
# 1/1 [==============================] - 0s 55ms/step
# banh bao
# 1/1 [==============================] - 0s 53ms/step
# banh bao
# 1/1 [==============================] - 0s 58ms/step
# banh mi
# 1/1 [==============================] - 0s 63ms/step
# banh mi
# 1/1 [==============================] - 0s 77ms/step
# banh mi
# 1/1 [==============================] - 0s 56ms/step
# banh mi
# 1/1 [==============================] - 0s 54ms/step
# banh mi
# 1/1 [==============================] - 0s 55ms/step
# bun gio
# 1/1 [==============================] - 0s 55ms/step
# banh mi
# 1/1 [==============================] - 0s 57ms/step
# bun gio
# 1/1 [==============================] - 0s 56ms/step
# bun gio
# 1/1 [==============================] - 0s 81ms/step
# bun gio
# 1/1 [==============================] - 0s 56ms/step
# xoi gac
# 1/1 [==============================] - 0s 60ms/step
# xoi gac
# 1/1 [==============================] - 0s 60ms/step
# xoi gac
# 1/1 [==============================] - 0s 54ms/step
# xoi gac
# 1/1 [==============================] - 0s 57ms/step
# xoi gac
